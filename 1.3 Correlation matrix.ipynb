# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import

# %%
df = pd.read_csv("Sales_no_outliers.csv")

# %% [markdown]
# # Filter for only the Brewery Category with more than 10 datapoints

# %%
brewery_df = df[df['GICS Sub-Industry'] == 'Brewers']
# Group the data by "Company Name" and count unique years for each group
company_years_count = brewery_df.groupby("Company Name")["Year"].nunique()

# Filter companies with at least 10 years of data
filtered_companies = company_years_count[company_years_count >= 10].index

# Create a new DataFrame with only the companies that meet the criteria
filtered_df = brewery_df[brewery_df["Company Name"].isin(filtered_companies)]
#filtered_df.shape

# %%
correlation_matrix = filtered_df.loc[:,"SDG 1.5":"SDG 15.5"].corr()

# %% [markdown]
# # Correlation Aanlysis

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ## Why we do not take the Correlation Matrix into account:
#
# Not taken into account, as the derived impacts lack independent variability due to the common calculation base, potentially leading to inflated or spurious correlations that don’t genuinely reflect inter-SDG dynamics. This, in turn, risks deriving misleading insights and may inadvertently guide strategic decision-making astray.

# %%
correlation_matrix = filtered_df.loc[:,"Working Capacity":"Wood Production Capacity"].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()
