# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_excel("Models\IWA_new.xlsx", sheet_name='Final Raw Sample(0%)')
df["Environmental Intensity (Op Inc)"] = df["Environmental Intensity (Op Inc)"]*100
df["Environmental Intensity (Sales)"] = df["Environmental Intensity (Sales)"]*100

# %%
# Calculate the 0.15th and 99.85th percentile
pct_0_15 = np.percentile(df['Environmental Intensity (Sales)'], 0.5)
pct_99_85 = np.percentile(df['Environmental Intensity (Sales)'], 99.5)

# Remove the data points outside the 0.15th and 99.85th percentile
df_new = df[(df['Environmental Intensity (Sales)'] >= pct_0_15) & (df['Environmental Intensity (Sales)'] <= pct_99_85)].copy()
df_new.describe()
# Out:
#                Year  Environmental Intensity (Sales)  \
# count  13893.000000                     13893.000000
# mean    2014.964658                       -10.694739
# std        2.784770                        23.234091
# min     2010.000000                      -162.929579
# 25%     2013.000000                        -8.980630
# 50%     2015.000000                        -2.028988
# 75%     2017.000000                        -0.696416
# max     2019.000000                        24.494820
#
#        Environmental Intensity (Op Inc)       Revenue  Operating Income  \
# count                      13146.000000  1.389300e+04      1.314600e+04
# mean                        -199.899847  1.349821e+10      1.613699e+09
# std                         2494.850465  3.063860e+10      3.908923e+09
# min                      -246289.416837  8.000000e+03     -1.490280e+09
# 25%                          -89.852181  1.370201e+09      1.554029e+08
# 50%                          -21.559498  4.145670e+09      4.275130e+08
# 75%                           -5.699460  1.248923e+10      1.267111e+09
# max                         7994.514465  6.740459e+11      7.071866e+10
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# count              1.389300e+04      1.389300e+04              1.389300e+04
# mean              -1.110886e+09     -9.742379e+08             -2.762829e+05
# std                4.633821e+09      4.074296e+09              1.093320e+06
# min               -1.144424e+11     -7.791808e+10             -1.888769e+07
# 25%               -4.392383e+08     -3.897905e+08             -9.931514e+04
# 50%               -9.371568e+07     -8.220170e+07             -2.184283e+04
# 75%               -2.079824e+07     -1.865820e+07             -5.094705e+03
# max                2.070037e+10      1.789551e+10              6.885299e+06
#
#        Crop Production Capacity  Meat Production Capacity  ...         SDG 6  \
# count              1.389300e+04              1.389300e+04  ...  1.389300e+04
# mean              -1.266070e+07             -2.941123e+06  ... -1.162445e+08
# std                5.199551e+07              1.208422e+07  ...  1.259866e+09
# min               -9.241874e+08             -2.161508e+08  ... -7.691509e+10
# 25%               -5.099930e+06             -1.182812e+06  ... -1.990371e+07
# 50%               -1.075420e+06             -2.507009e+05  ... -2.605121e+06
# 75%               -2.433520e+05             -5.664645e+04  ... -2.957296e+05
# max                2.398745e+08              5.648686e+07  ...  3.972227e+09
#
#            SDG 12.2       SDG 14.1       SDG 14.2      SDG 14.3  \
# count  1.389300e+04   13893.000000   13893.000000  1.389300e+04
# mean  -4.543339e+06   -4398.262404   -1836.766072 -1.302077e+05
# std    1.006142e+08   22999.380991   14401.953024  5.149272e+05
# min   -4.485891e+09 -483554.391700 -637843.776412 -9.017876e+06
# 25%   -8.817605e+04    -571.152340    -212.208272 -4.734983e+04
# 50%   -1.079221e+04     -87.620616     -28.789806 -1.052252e+04
# 75%   -1.860237e+03     -14.300864      -4.300370 -2.431545e+03
# max    0.000000e+00  189956.254000       0.005117  3.236546e+06
#
#             SDG 14.c      SDG 15.1      SDG 15.2      SDG 15.5     % Imputed
# count   13893.000000  1.389300e+04  1.389300e+04  1.389300e+04  13893.000000
# mean    -5226.249463  5.245506e+04  9.841959e+03 -4.009458e+04      0.066154
# std     27349.765462  3.336232e+05  2.282687e+06  1.639132e+05      0.067436
# min   -576362.772700 -3.991837e+06 -1.591757e+08 -2.907937e+06      0.000000
# 25%      -680.773357  7.270353e+01  6.623705e+01 -1.603986e+04      0.011726
# 50%      -104.437602  7.185165e+02  6.898681e+02 -3.410759e+03      0.039804
# 75%       -17.045622  6.037115e+03  5.798490e+03 -7.731023e+02      0.104377
# max    226412.474000  7.146112e+06  7.146112e+06  7.833655e+05      0.249715
#
# [8 rows x 32 columns]

# %%
df_new.to_csv("Sales_no_outliers.csv")

# %%
df_rev = df_new.copy()
for column in df_rev.loc[:,"Working Capacity":"SDG 15.5"]:
    #print(column)
    df_rev[column] = (df_rev[column] / df_rev['Revenue'])*100

# %%
df_rev.to_csv("Sales_no_outliers_percentage.csv")

# %%
df_rev.describe()
# Out:
#                Year  Environmental Intensity (Sales)  \
# count  13893.000000                     13893.000000
# mean    2014.964658                       -10.694739
# std        2.784770                        23.234091
# min     2010.000000                      -162.929579
# 25%     2013.000000                        -8.980630
# 50%     2015.000000                        -2.028988
# 75%     2017.000000                        -0.696416
# max     2019.000000                        24.494820
#
#        Environmental Intensity (Op Inc)       Revenue  Operating Income  \
# count                      13146.000000  1.389300e+04      1.314600e+04
# mean                        -199.899847  1.349821e+10      1.613699e+09
# std                         2494.850465  3.063860e+10      3.908923e+09
# min                      -246289.416837  8.000000e+03     -1.490280e+09
# 25%                          -89.852181  1.370201e+09      1.554029e+08
# 50%                          -21.559498  4.145670e+09      4.275130e+08
# 75%                           -5.699460  1.248923e+10      1.267111e+09
# max                         7994.514465  6.740459e+11      7.071866e+10
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# count              1.389300e+04      13893.000000              13893.000000
# mean              -1.110886e+09         -9.254608                 -0.002585
# std                4.633821e+09         20.543333                  0.005759
# min               -1.144424e+11       -158.555255                 -0.062731
# 25%               -4.392383e+08         -7.769470                 -0.002095
# 50%               -9.371568e+07         -1.808851                 -0.000461
# 75%               -2.079824e+07         -0.647058                 -0.000168
# max                2.070037e+10         24.674110                  0.007874
#
#        Crop Production Capacity  Meat Production Capacity  ...         SDG 6  \
# count              13893.000000              13893.000000  ...  13893.000000
# mean                  -0.120722                 -0.028142  ...     -1.268764
# std                    0.268390                  0.062774  ...      6.672177
# min                   -2.110091                 -0.493695  ...   -150.613951
# 25%                   -0.101493                 -0.023566  ...     -0.366356
# 50%                   -0.023688                 -0.005518  ...     -0.054217
# 75%                   -0.008464                 -0.001964  ...     -0.009610
# max                    0.418551                  0.096199  ...     28.495982
#
#            SDG 12.2      SDG 14.1      SDG 14.2      SDG 14.3      SDG 14.c  \
# count  13893.000000  1.389300e+04  1.389300e+04  13893.000000  1.389300e+04
# mean      -0.019961 -3.745822e-05 -1.377963e-05     -0.001229 -4.244979e-05
# std        0.272979  2.574877e-04  5.603316e-05      0.002736  1.633059e-04
# min      -11.340237 -2.573223e-02 -9.107194e-04     -0.027277 -5.690773e-03
# 25%       -0.001799 -8.357705e-06 -3.642929e-06     -0.001004 -9.961795e-06
# 50%       -0.000182 -1.497232e-06 -6.136105e-07     -0.000221 -1.784595e-06
# 75%       -0.000064 -5.703129e-07 -1.324895e-07     -0.000081 -6.797728e-07
# max        0.000000  1.998351e-04  5.816653e-12      0.003701  2.381893e-04
#
#            SDG 15.1      SDG 15.2      SDG 15.5     % Imputed
# count  13893.000000  13893.000000  13893.000000  13893.000000
# mean       0.000435      0.000028     -0.000383      0.066154
# std        0.001942      0.018957      0.000848      0.067436
# min       -0.008381     -1.147740     -0.006684      0.000000
# 25%        0.000006      0.000006     -0.000323      0.011726
# 50%        0.000016      0.000016     -0.000075      0.039804
# 75%        0.000078      0.000075     -0.000027      0.104377
# max        0.069434      0.069434      0.001109      0.249715
#
# [8 rows x 32 columns]
