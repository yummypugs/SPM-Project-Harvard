# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 df = pd.read_excel("/content/drive/MyDrive/MADS/SPM/Project/IWA.xlsx", sheet_name='Final Raw Sample(0%)')
 df.head()
# Out:
#    Year        Company Name  \
# 0  2019            SAGA PLC
# 1  2019  BURSA MALAYSIA BHD
# 2  2019  INTERTEK GROUP PLC
# 3  2019         JSE LIMITED
# 4  2019   BUREAU VERITAS SA
#
#                                              Country  \
# 0  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 1                                           MALAYSIA
# 2  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 3                                       SOUTH AFRICA
# 4                                             FRANCE
#
#                 GICS Sub-Industry  \
# 0            Multi-line Insurance
# 1      Financial Exchanges & Data
# 2  Research & Consulting Services
# 3      Financial Exchanges & Data
# 4  Research & Consulting Services
#
#                                  Industry (Exiobase)  \
# 0  Activities auxiliary to financial intermediati...
# 1  Activities auxiliary to financial intermediati...
# 2  Activities auxiliary to financial intermediati...
# 3  Activities auxiliary to financial intermediati...
# 4  Activities auxiliary to financial intermediati...
#
#    Environmental Intensity (Sales)  Environmental Intensity (Op Inc)  \
# 0                        -0.028872                         -0.130254
# 1                        -0.016772                         -0.034656
# 2                        -0.015297                         -0.094878
# 3                        -0.014625                               NaN
# 4                        -0.006993                         -0.050957
#
#    Total Environmental Cost  Working Capacity  Fish Production Capacity  ...  \
# 0             -3.184231e+07     -3.115075e+07              -7184.203318  ...
# 1             -1.968379e+06     -1.924910e+06               -451.342112  ...
# 2             -6.059927e+07     -5.928166e+07             -13774.014902  ...
# 3             -2.290124e+06     -2.239814e+06               -510.210093  ...
# 4             -3.997865e+07     -3.910761e+07              -9330.459280  ...
#
#            SDG 6     SDG 12.2   SDG 14.1  SDG 14.2     SDG 14.3   SDG 14.c  \
# 0 -170775.886453 -1059.042606  -4.739468 -1.027193 -3584.970569  -5.649112
# 1  -11502.243880  -168.146428  -1.410813 -1.207108  -222.196310  -1.681590
# 2 -324959.759255 -3804.051175 -17.024036 -3.689647 -6861.392776 -20.291452
# 3  -12199.928822  -901.413470  -0.189720 -1.009642  -253.366805  -0.226133
# 4 -214438.078273 -4116.308632 -37.818819 -9.136488 -4606.916825 -45.077368
#
#      SDG 15.1    SDG 15.2     SDG 15.5  % Imputed
# 0   70.667599   70.667599 -1297.277948   0.006135
# 1   10.138780   10.138780   -79.398691   0.043215
# 2  253.836024  253.836024 -2470.054721   0.011467
# 3   -3.169102   -3.169102   -92.619013   0.016390
# 4  586.030400  586.030400 -1632.997165   0.033005
#
# [5 rows x 34 columns]

# %%
semiconductors_df = df[df['GICS Sub-Industry'] == 'Semiconductors']
semiconductors_df
# Out:
#        Year                  Company Name                    Country  \
# 544    2019   VANGUARD INTL SEMICONDUCTOR  TAIWAN, PROVINCE OF CHINA
# 547    2019         ON SEMICONDUCTOR CORP   UNITED STATES OF AMERICA
# 550    2019  UNITED MICROELECTRONICS CORP  TAIWAN, PROVINCE OF CHINA
# 551    2019       WALTON ADVANCED ENG INC  TAIWAN, PROVINCE OF CHINA
# 13417  ... -9.755134e+04 -4.120809e+03  -51.972762  -30.818624  -2209.637247
# 13421  ... -2.026601e+06 -1.650811e+05  -53.238577  -34.813867   -994.003814
# 13422  ... -6.168118e+06 -1.000175e+06 -322.555994 -210.926400  -6026.362887
# 13430  ... -1.831652e+07 -4.441247e+04 -560.142131 -332.095164  59360.959299
#
#          SDG 14.c     SDG 15.1     SDG 15.2      SDG 15.5  % Imputed
# 544    -45.408327   461.058008   461.058008  -9322.613928   0.007411
# 547   -342.508573  3006.743867  3006.743867 -35008.897062   0.169190
# 550   -106.173728   782.226632   782.226632 -29938.300593   0.004732
# 551    -10.799618   109.655005   109.655005  -1341.772299   0.013895
# 552    -14.322912   151.830381   151.830381  -4090.525684   0.029233
# ...           ...          ...          ...           ...        ...
# 13416 -163.489152  1435.204970  1435.204970  -1583.564090   0.155052
# 13417  -61.947871   628.993935   628.993935   -748.237945   0.124131
# 13421  -63.456634   557.060055   557.060055   -311.899180   0.227818
# 13422 -384.464024  3375.053757  3375.053757  -1891.157188   0.245612
# 13430 -667.649963  6779.050963  6779.050963  22250.264939   0.047516
#
# [327 rows x 34 columns]

# %%
# Group the data by "Company Name" and count unique years for each group
company_years_count = semiconductors_df.groupby("Company Name")["Year"].nunique()

# Filter companies with at least 10 years of data
filtered_companies = company_years_count[company_years_count >= 10].index

# Create a new DataFrame with only the companies that meet the criteria
filtered_df = semiconductors_df[semiconductors_df["Company Name"].isin(filtered_companies)]

# %%
filtered_df
# Out:
#        Year                  Company Name                    Country  \
# 544    2019   VANGUARD INTL SEMICONDUCTOR  TAIWAN, PROVINCE OF CHINA
# 550    2019  UNITED MICROELECTRONICS CORP  TAIWAN, PROVINCE OF CHINA
# 559    2019          MACRONIX INTL CO LTD  TAIWAN, PROVINCE OF CHINA
# 581    2019      POWERTECH TECHNOLOGY INC  TAIWAN, PROVINCE OF CHINA
# 582    2019                   ROHM CO LTD                      JAPAN
# ...     ...                           ...                        ...
# 13397  2010      POWERTECH TECHNOLOGY INC  TAIWAN, PROVINCE OF CHINA
# 13398  2010                   ROHM CO LTD                      JAPAN
# 13402  2010         TEXAS INSTRUMENTS INC   UNITED STATES OF AMERICA
# 13404  2010               FIRST SOLAR INC   UNITED STATES OF AMERICA
# 13411  2010                    INTEL CORP   UNITED STATES OF AMERICA
#
#       GICS Sub-Industry                                Industry (Exiobase)  \
# 544      Semiconductors  Manufacture of electrical machinery and appara...
# 550      Semiconductors  Manufacture of electrical machinery and appara...
# 559      Semiconductors  Manufacture of electrical machinery and appara...
# 581      Semiconductors  Manufacture of electrical machinery and appara...
# 582      Semiconductors  Manufacture of electrical machinery and appara...
# ...                 ...                                                ...
# 13397    Semiconductors  Manufacture of electrical machinery and appara...
# 13398    Semiconductors  Manufacture of electrical machinery and appara...
# 13402    Semiconductors  Manufacture of electrical machinery and appara...
# 13404    Semiconductors  Manufacture of electrical machinery and appara...
# 550     0.004732
# 559     0.005121
# 581     0.012212
# 582     0.001780
# ...          ...
# 13397   0.036247
# 13398   0.000145
# 13402   0.025526
# 13404   0.074137
# 13411   0.047685
#
# [100 rows x 34 columns]

# %%
filtered_df.shape
# Out:
# (100, 34)

# %%
# Create a unique list of company names
company_names = filtered_df["Company Name"].unique()

# Set up the plot
plt.figure(figsize=(12, 6))

# Function to format Y-axis labels in thousands
def thousands(x, pos):
    'The two args are the value and tick position'
    return f'{x / 1000:.0f}K'

# Create a FuncFormatter object using the thousands function
formatter = FuncFormatter(thousands)

# Iterate through each company and plot its annual trend
for company in company_names:
    company_data = filtered_df[filtered_df["Company Name"] == company]
    plt.plot(company_data["Year"], company_data["Total Environmental Cost"], label=company)

# Add labels and legend
plt.xlabel("Year")
plt.ylabel("Total Environmental Cost (Thousands of Dollars)")
plt.title("Annual Trend of Total Environmental Cost by Company")
plt.legend(loc="best")

# Apply the Y-axis label formatting
plt.gca().yaxis.set_major_formatter(formatter)

# Show the plot
plt.grid()
plt.show()

# %%
# Create a unique list of company names
company_names = filtered_df["Company Name"].unique()

# Set up the plot
plt.figure(figsize=(12, 6))

# Function to format Y-axis labels as percentages
def percentage(x, pos):
    return f'{x:.0%}'

# Create a FuncFormatter object using the percentage function
formatter = FuncFormatter(percentage)

# Iterate through each company and plot its annual trend
for company in company_names:
    company_data = filtered_df[filtered_df["Company Name"] == company]
    plt.plot(company_data["Year"], company_data["Environmental Intensity (Sales)"], label=company)

# Add labels and legend
plt.xlabel("Year")
plt.ylabel("Environmental Intensity (Sales)")
plt.title("Annual Trend of Environmental Intensity on Sales by Company")
plt.legend(loc="best")

# Apply the Y-axis label formatting as percentages
plt.gca().yaxis.set_major_formatter(formatter)

# Show the plot
plt.grid()
plt.show()

# %%
new_df = filtered_df[["Company Name","Environmental Intensity (Sales)",
                      "Working Capacity", "Fish Production Capacity", "Crop Production Capacity",
                      "Meat Production Capacity", "Biodiversity", "Abiotic Resources",
                      "Water production capacity (Drinking water & Irrigation Water)", "Wood Production Capacity"]]
new_df = new_df.reset_index()
new_df = new_df.drop("index", axis=1)
new_df
# Out:
#                     Company Name  Environmental Intensity (Sales)  \
# 0    VANGUARD INTL SEMICONDUCTOR                        -0.248834
# 1   UNITED MICROELECTRONICS CORP                        -0.152112
# 2           MACRONIX INTL CO LTD                        -0.116371
# 3       POWERTECH TECHNOLOGY INC                        -0.059186
# 4                    ROHM CO LTD                        -0.055297
# ..                           ...                              ...
# 95      POWERTECH TECHNOLOGY INC                        -0.054307
# 96                   ROHM CO LTD                        -0.054161
# 97         TEXAS INSTRUMENTS INC                        -0.048182
# 98               FIRST SOLAR INC                        -0.036372
# 99                    INTEL CORP                        -0.025616
#
#     Working Capacity  Fish Production Capacity  Crop Production Capacity  \
# 0      -2.241057e+08             -51608.241955             -2.977838e+06
# 1      -7.201719e+08            -165596.905315             -9.559184e+06
# 2      -1.308858e+08             -29929.205341             -1.736436e+06
# 3      -1.270118e+08             -29010.724700             -1.682068e+06
# 4      -1.890929e+08             -44004.157255             -2.516677e+06
# ..               ...                       ...                       ...
# 95     -6.886690e+07             -16207.461695             -9.134439e+05
# 96     -2.111819e+08             -64632.027555             -2.820921e+06
# 97     -6.154968e+08            -140612.361583             -8.077119e+06
# 98     -8.337028e+07             -19996.596265             -1.095669e+06
# 99     -9.970025e+08            -226885.928627             -1.291560e+07
#
#     Meat Production Capacity  Biodiversity  Abiotic Resources  \
# 0              -6.980213e+05  -9361.183144      -3.020589e+03
# 1              -2.240606e+06 -30028.483114      -1.582604e+04
# 2              -4.069154e+05  -5443.332866      -3.737062e+03
# 3              -3.929992e+05  -5260.753996      -7.104034e+03
# 4              -5.891283e+05  -7928.270364      -1.870812e+03
# ..                       ...           ...                ...
# 95             -2.134952e+05  -2908.373205      -4.004698e+03
# 96             -6.617531e+05 -10212.662682      -1.503062e+03
# 97             -1.892487e+06 -25419.492136      -2.150978e+06
# 98             -2.555728e+05  -3549.697078      -3.908075e+05
# 99             -3.025051e+06 -40796.831338      -6.718610e+06
#
#     Water production capacity (Drinking water & Irrigation Water)  \
# 0                                       -7.453941e+06
# 1                                       -2.144053e+07
# 2                                       -3.073505e+06
# 3                                       -2.496389e+06
# 4                                       -6.755350e+06
# ..                                                ...
# 95                                      -3.754074e+05
# 96                                      -9.454682e+06
# 97                                      -4.512573e+07
# 98                                      -7.159446e+06
# 99                                      -9.749781e+07
#
#     Wood Production Capacity
# 0                 922.116017
# 1                1564.453264
# 2                 -31.350220
# 3                -442.328492
# 4                1512.288260
# ..                       ...
# 95               1222.542083
# 96              35058.080097
# 97              -3164.342910
# 98               2637.530191
# 99             -12106.132122
#
# [100 rows x 10 columns]

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
X = new_df[["Working Capacity", "Fish Production Capacity", "Crop Production Capacity",
                      "Meat Production Capacity", "Biodiversity", "Abiotic Resources",
                      "Water production capacity (Drinking water & Irrigation Water)", "Wood Production Capacity"]]
y = new_df[["Environmental Intensity (Sales)"]]
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     Environmental Intensity (Sales)   R-squared:                       0.446
# Model:                                         OLS   Adj. R-squared:                  0.397
# Method:                              Least Squares   F-statistic:                     9.149
# Date:                             Thu, 21 Sep 2023   Prob (F-statistic):           3.73e-09
# Time:                                     08:55:57   Log-Likelihood:                 157.65
# No. Observations:                              100   AIC:                            -297.3
# Df Residuals:                                   91   BIC:                            -273.9
# Df Model:                                        8
# Covariance Type:                         nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# const                                                            -0.1281      0.011    -11.668      0.000      -0.150      -0.106
# Working Capacity                                              -4.706e-06    1.8e-06     -2.618      0.010   -8.28e-06   -1.14e-06
# Fish Production Capacity                                         -0.0033      0.001     -2.704      0.008      -0.006      -0.001
# Crop Production Capacity                                          0.0001   4.78e-05      2.383      0.019     1.9e-05       0.000
# Meat Production Capacity                                         -0.0008      0.000     -2.495      0.014      -0.001      -0.000
# Biodiversity                                                      0.1568      0.059      2.637      0.010       0.039       0.275
# Abiotic Resources                                              2.688e-06   1.02e-06      2.633      0.010     6.6e-07    4.72e-06
# Water production capacity (Drinking water & Irrigation Water) -7.179e-10   3.95e-10     -1.819      0.072    -1.5e-09     6.6e-11
# Wood Production Capacity                                          0.0048      0.002      2.617      0.010       0.001       0.008
# ==============================================================================
# Omnibus:                       19.684   Durbin-Watson:                   1.445
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.956
# Skew:                          -1.084   Prob(JB):                     6.28e-06
# Kurtosis:                       4.024   Cond. No.                     5.95e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.95e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # With Revenue

# %%
with_rev = filtered_df.copy()
with_rev
# Out:
#        Year                  Company Name                    Country  \
# 544    2019   VANGUARD INTL SEMICONDUCTOR  TAIWAN, PROVINCE OF CHINA
# 550    2019  UNITED MICROELECTRONICS CORP  TAIWAN, PROVINCE OF CHINA
# 559    2019          MACRONIX INTL CO LTD  TAIWAN, PROVINCE OF CHINA
# 581    2019      POWERTECH TECHNOLOGY INC  TAIWAN, PROVINCE OF CHINA
# 582    2019                   ROHM CO LTD                      JAPAN
# ...     ...                           ...                        ...
# 13397  2010      POWERTECH TECHNOLOGY INC  TAIWAN, PROVINCE OF CHINA
# 13398  2010                   ROHM CO LTD                      JAPAN
# 13402  2010         TEXAS INSTRUMENTS INC   UNITED STATES OF AMERICA
# 13404  2010               FIRST SOLAR INC   UNITED STATES OF AMERICA
# 13411  2010                    INTEL CORP   UNITED STATES OF AMERICA
#
#       GICS Sub-Industry                                Industry (Exiobase)  \
# 544      Semiconductors  Manufacture of electrical machinery and appara...
# 550      Semiconductors  Manufacture of electrical machinery and appara...
# 559      Semiconductors  Manufacture of electrical machinery and appara...
# 581      Semiconductors  Manufacture of electrical machinery and appara...
# 582      Semiconductors  Manufacture of electrical machinery and appara...
# ...                 ...                                                ...
# 13397    Semiconductors  Manufacture of electrical machinery and appara...
# 13398    Semiconductors  Manufacture of electrical machinery and appara...
# 13402    Semiconductors  Manufacture of electrical machinery and appara...
# 13404    Semiconductors  Manufacture of electrical machinery and appara...
# 13411    Semiconductors  Manufacture of electrical machinery and appara...
#
#        Environmental Intensity (Sales)  Environmental Intensity (Op Inc)  \
# 544                          -0.248834                         -1.041840
# 550                          -0.152112                               NaN
# 559                          -0.116371                         -1.344026
# 581                          -0.059186                         -0.462201
# 582                          -0.055297                         -0.386256
# ...                                ...                               ...
# 13397                        -0.054307                         -0.243988
# 13398                        -0.054161                         -0.966493
# 13402                        -0.048182                         -0.152830
# 13404                        -0.036372                         -0.126067
# 13411                        -0.025616                         -0.072046
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# 544               -2.352986e+08     -2.241057e+08             -51608.241955
# 550               -7.536221e+08     -7.201719e+08            -165596.905315
# 559               -1.361418e+08     -1.308858e+08             -29929.205341
# 13411  ... -6.718610e+06  -223.109980 -1416.717448 -111054.725279
#
#           SDG 14.c      SDG 15.1      SDG 15.2      SDG 15.5  % Imputed  \
# 544     -45.408327    461.058008    461.058008  -9322.613928   0.007411
# 550    -106.173728    782.226632    782.226632 -29938.300593   0.004732
# 559      -8.909944    -15.675110    -15.675110  -5435.764881   0.005121
# 581      -1.503631   -221.164246   -221.164246  -5259.476832   0.012212
# 582     -61.512165    756.144130    756.144130  -7876.022767   0.001780
# ...            ...           ...           ...           ...        ...
# 13397   -60.202393    611.271042    611.271042  -2857.238111   0.036247
# 13398 -1414.158460  17529.040049  17529.040049  -9011.495716   0.000145
# 13402  -113.828570  -1582.171455  -1582.171455 -25322.842554   0.025526
# 13404  -150.225084   1318.765096   1318.765096  -3422.104267   0.074137
# 13411  -265.931380  -6053.066061  -6053.066061 -40571.061718   0.047685
#
#             Revenue
# 544    9.456030e+08
# 550    4.954381e+09
# 559    1.169897e+09
# 581    2.223936e+09
# 582    3.598881e+09
# ...             ...
# 13397  1.296179e+09
# 13398  4.138743e+09
# 13402  1.396600e+10
# 13404  2.537459e+09
# 13411  4.362300e+10
#
# [100 rows x 35 columns]

# %%
with_rev_new = with_rev[["Company Name","Revenue",
                      "Working Capacity", "Fish Production Capacity", "Crop Production Capacity",
                      "Meat Production Capacity", "Biodiversity", "Abiotic Resources",
                      "Water production capacity (Drinking water & Irrigation Water)", "Wood Production Capacity"]]
with_rev_new = with_rev_new.reset_index()
with_rev_new = with_rev_new.drop("index", axis=1)
with_rev_new
# Out:
#                     Company Name       Revenue  Working Capacity  \
# 0    VANGUARD INTL SEMICONDUCTOR  9.456030e+08     -2.241057e+08
# 1   UNITED MICROELECTRONICS CORP  4.954381e+09     -7.201719e+08
# 2           MACRONIX INTL CO LTD  1.169897e+09     -1.308858e+08
# 3       POWERTECH TECHNOLOGY INC  2.223936e+09     -1.270118e+08
# 4                    ROHM CO LTD  3.598881e+09     -1.890929e+08
# ..                           ...           ...               ...
# 95      POWERTECH TECHNOLOGY INC  1.296179e+09     -6.886690e+07
# 96                   ROHM CO LTD  4.138743e+09     -2.111819e+08
# 97         TEXAS INSTRUMENTS INC  1.396600e+10     -6.154968e+08
# 98               FIRST SOLAR INC  2.537459e+09     -8.337028e+07
# 99                    INTEL CORP  4.362300e+10     -9.970025e+08
#
#     Fish Production Capacity  Crop Production Capacity  \
# 0              -51608.241955             -2.977838e+06
# 1             -165596.905315             -9.559184e+06
# 2              -29929.205341             -1.736436e+06
# 3              -29010.724700             -1.682068e+06
# 4              -44004.157255             -2.516677e+06
# ..                       ...                       ...
# 95             -16207.461695             -9.134439e+05
# 96             -64632.027555             -2.820921e+06
# 97            -140612.361583             -8.077119e+06
# 98             -19996.596265             -1.095669e+06
# 99            -226885.928627             -1.291560e+07
#
#     Meat Production Capacity  Biodiversity  Abiotic Resources  \
# 0              -6.980213e+05  -9361.183144      -3.020589e+03
# 1              -2.240606e+06 -30028.483114      -1.582604e+04
# 2              -4.069154e+05  -5443.332866      -3.737062e+03
# 3              -3.929992e+05  -5260.753996      -7.104034e+03
# 4              -5.891283e+05  -7928.270364      -1.870812e+03
# ..                       ...           ...                ...
# 95             -2.134952e+05  -2908.373205      -4.004698e+03
# 96             -6.617531e+05 -10212.662682      -1.503062e+03
# 97             -1.892487e+06 -25419.492136      -2.150978e+06
# 98             -2.555728e+05  -3549.697078      -3.908075e+05
# 99             -3.025051e+06 -40796.831338      -6.718610e+06
#
#     Water production capacity (Drinking water & Irrigation Water)  \
# 0                                       -7.453941e+06
# 1                                       -2.144053e+07
# 2                                       -3.073505e+06
# 3                                       -2.496389e+06
# 4                                       -6.755350e+06
# ..                                                ...
# 95                                      -3.754074e+05
# 96                                      -9.454682e+06
# 97                                      -4.512573e+07
# 98                                      -7.159446e+06
# 99                                      -9.749781e+07
#
#     Wood Production Capacity
# 0                 922.116017
# 1                1564.453264
# 2                 -31.350220
# 3                -442.328492
# 4                1512.288260
# ..                       ...
# 95               1222.542083
# 96              35058.080097
# 97              -3164.342910
# 98               2637.530191
# 99             -12106.132122
#
# [100 rows x 10 columns]

# %%
X = with_rev_new[["Working Capacity", "Fish Production Capacity", "Crop Production Capacity",
                      "Meat Production Capacity", "Biodiversity", "Abiotic Resources",
                      "Water production capacity (Drinking water & Irrigation Water)", "Wood Production Capacity"]]
y = np.log(with_rev_new[["Revenue"]])
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Revenue   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     90.04
# Date:                Thu, 21 Sep 2023   Prob (F-statistic):           7.37e-40
# Time:                        08:55:57   Log-Likelihood:                -54.941
# No. Observations:                 100   AIC:                             127.9
# Df Residuals:                      91   BIC:                             151.3
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# const                                                            20.6334      0.092    224.191      0.000      20.451      20.816
# Working Capacity                                              -5.689e-05   1.51e-05     -3.776      0.000   -8.68e-05    -2.7e-05
# Fish Production Capacity                                         -0.0403      0.010     -3.913      0.000      -0.061      -0.020
# Crop Production Capacity                                          0.0014      0.000      3.505      0.001       0.001       0.002
# Meat Production Capacity                                         -0.0102      0.003     -3.677      0.000      -0.016      -0.005
# Biodiversity                                                      1.9041      0.499      3.819      0.000       0.914       2.894
# Abiotic Resources                                              3.172e-05   8.56e-06      3.708      0.000    1.47e-05    4.87e-05
# Water production capacity (Drinking water & Irrigation Water) -8.455e-09   3.31e-09     -2.556      0.012    -1.5e-08   -1.89e-09
# Wood Production Capacity                                          0.0581      0.015      3.791      0.000       0.028       0.089
# ==============================================================================
# Omnibus:                        3.714   Durbin-Watson:                   1.584
# Prob(Omnibus):                  0.156   Jarque-Bera (JB):                3.723
# Skew:                          -0.445   Prob(JB):                        0.155
# Kurtosis:                       2.679   Cond. No.                     5.95e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.95e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
