# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the Excel

# %% [markdown]
# ## Create the Revenue Column based on the Intensity and Total Environmental Cost

# %%
# Load the dataset
df = pd.read_excel("Models\IWA.xlsx", sheet_name='Final Raw Sample(0%)')
df["Revenue"] = df["Total Environmental Cost"]/df["Environmental Intensity (Sales)"]
df["Operating Income"] = df["Total Environmental Cost"]/df["Environmental Intensity (Op Inc)"]
df["Environmental Intensity (Op Inc)"] = df["Environmental Intensity (Op Inc)"]*100
df["Environmental Intensity (Sales)"] = df["Environmental Intensity (Sales)"]*100
df = df.drop("Industry (Exiobase)", axis=1)
df.head()
# Out:
#    Year        Company Name  \
# 0  2019            SAGA PLC
# 1  2019  BURSA MALAYSIA BHD
# 2  2019  INTERTEK GROUP PLC
# 3  2019         JSE LIMITED
# 4  2019   BUREAU VERITAS SA
#
#                                              Country  \
# 0  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 1                                           MALAYSIA
# 2  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 3                                       SOUTH AFRICA
# 4                                             FRANCE
#
#                 GICS Sub-Industry  Environmental Intensity (Sales)  \
# 0            Multi-line Insurance                        -2.887178
# 1      Financial Exchanges & Data                        -1.677157
# 2  Research & Consulting Services                        -1.529690
# 3      Financial Exchanges & Data                        -1.462497
# 4  Research & Consulting Services                        -0.699273
#
#    Environmental Intensity (Op Inc)  Total Environmental Cost  \
# 0                        -13.025357             -3.184231e+07
# 1                         -3.465639             -1.968379e+06
# 2                         -9.487849             -6.059927e+07
# 3                               NaN             -2.290124e+06
# 4                         -5.095678             -3.997865e+07
#
#    Working Capacity  Fish Production Capacity  Crop Production Capacity  ...  \
# 0     -3.115075e+07              -7184.203318            -414256.439748  ...
# 1     -1.924910e+06               -451.342112             -25348.722429  ...
# 2     -5.928166e+07             -13774.014902            -788289.414697  ...
# 3     -2.239814e+06               -510.210093             -29661.954007  ...
# 4     -3.910761e+07              -9330.459280            -520701.497769  ...
#
#     SDG 14.1  SDG 14.2     SDG 14.3   SDG 14.c    SDG 15.1    SDG 15.2  \
# 0  -4.739468 -1.027193 -3584.970569  -5.649112   70.667599   70.667599
# 1  -1.410813 -1.207108  -222.196310  -1.681590   10.138780   10.138780
# 2 -17.024036 -3.689647 -6861.392776 -20.291452  253.836024  253.836024
# 3  -0.189720 -1.009642  -253.366805  -0.226133   -3.169102   -3.169102
# 4 -37.818819 -9.136488 -4606.916825 -45.077368  586.030400  586.030400
#
#       SDG 15.5  % Imputed       Revenue  Operating Income
# 0 -1297.277948   0.006135  1.102887e+09       244464000.0
# 1   -79.398691   0.043215  1.173640e+08        56797000.0
# 2 -2470.054721   0.011467  3.961539e+09       638704000.0
# 3   -92.619013   0.016390  1.565900e+08               NaN
# 4 -1632.997165   0.033005  5.717172e+09       784560000.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Filter for only Molson Company

# %%
molson_df = df[df['Company Name'] == 'MOLSON COORS BEVERAGE CO']
# Group the data by "Company Name" and count unique years for each group
molson_df
# Out:
#        Year              Company Name                   Country  \
# 517    2019  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 2194   2018  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 3815   2017  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 5728   2016  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 7017   2015  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 8504   2014  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 9886   2013  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 11175  2012  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 12312  2011  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 13364  2010  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
#
#       GICS Sub-Industry  Environmental Intensity (Sales)  \
# 517             Brewers                        -6.596233
# 2194            Brewers                        -4.448054
# 3815            Brewers                        -4.381103
# 5728            Brewers                        -2.381480
# 7017            Brewers                        -3.841844
# 8504            Brewers                        -3.623766
# 9886            Brewers                        -3.915211
# 11175           Brewers                        -3.584276
# 12312           Brewers                        -3.884249
# 13364           Brewers                        -4.548408
#
#        Environmental Intensity (Op Inc)  Total Environmental Cost  \
# 517                          -46.522794             -6.978419e+08
# 2194                         -36.115626             -4.790377e+08
# 3815                         -27.921920             -4.820440e+08
# 5728                         -23.947160             -1.163353e+08
# 7017                         -36.048861             -1.370578e+08
# 8504                         -31.446673             -1.502522e+08
# 9886                         -35.644519             -1.646777e+08
# 11175                        -28.896289             -1.403782e+08
# 12312                        -29.564524             -1.365585e+08
# 13364                        -34.185540             -1.480234e+08
#
#        Working Capacity  Fish Production Capacity  Crop Production Capacity  \
# 517       -2.950986e+08             -77656.206578             -3.917870e+06
# 2194      -3.142881e+08             -82227.448289             -4.172960e+06
# 3815      -3.210202e+08             -83991.181201             -4.262344e+06
# 5728      -6.232402e+07             -18949.115196             -8.257291e+05
# 7017      -6.990357e+07             -19400.517538             -9.273968e+05
# 8504      -8.745990e+07             -23669.882877             -1.160719e+06
# 9886      -9.313734e+07             -24739.811068             -1.236381e+06
# 11175     -5.826990e+07             -16642.815125             -7.727384e+05
# 12312     -6.069886e+07             -17207.533220             -8.050365e+05
# 13364     -3.412893e+07             -23683.496209             -4.132155e+05
#
#        ...     SDG 14.1    SDG 14.2      SDG 14.3     SDG 14.c      SDG 15.1  \
# 517    ... -1113.208360 -326.988191 -37024.568588 -1326.865949  15176.840942
# 2194   ... -1133.221993 -332.866895 -39277.764892 -1350.720790  15449.695276
# 3815   ... -1157.760264 -340.074642 -40119.876325 -1379.968681  15784.235922
# 5728   ...  -514.019967 -150.985624  -8641.781920  -612.675592   7007.851863
# 7017   ...  -373.712597 -109.772448  -9094.798316  -445.439091   5094.982084
# 8504   ...  -401.563122 -117.953120 -11184.359704  -478.634955   5474.680081
# 9886   ...  -376.562027 -110.609424 -11759.828655  -448.835410   5133.829560
# 11175  ...  -363.070308 -106.646435  -7733.188929  -432.754232   4949.891252
# 12312  ...  -364.082399 -106.943722  -8013.908265  -433.960573   4963.689513
# 13364  ...  -679.755640  -96.272976 -10895.552725  -810.220840   9670.848304
#
#            SDG 15.2      SDG 15.5  % Imputed       Revenue  Operating Income
# 517    15176.840942 -12261.768244   0.059202  1.057940e+10      1.500000e+09
# 2194   15449.695276 -13060.087217   0.083980  1.076960e+10      1.326400e+09
# 3815   15784.235922 -13339.829917   0.085090  1.100280e+10      1.726400e+09
# 5728    7007.851863  -2584.493608   0.140587  4.885000e+09      4.858000e+08
# 7017    5094.982084  -2902.558191   0.094867  3.567500e+09      3.802000e+08
# 8504    5474.680081  -3632.758703   0.093264  4.146300e+09      4.778000e+08
# 9886    5133.829560  -3869.522589   0.081540  4.206100e+09      4.620000e+08
# 11175   4949.891252  -2418.547980   0.090688  3.916500e+09      4.858000e+08
# 12312   4963.689513  -2519.625387   0.093072  3.515700e+09      4.619000e+08
# 13364   9670.848304  -1611.055691   0.010385  3.254400e+09      4.330000e+08
#
# [10 rows x 35 columns]

# %% [markdown]
# # Boxplots
#
# ## Absoulte Values

# %%
df_abs_box = molson_df.melt(id_vars='GICS Sub-Industry', value_vars=[ "Working Capacity","Fish Production Capacity","Crop Production Capacity","Meat Production Capacity","Biodiversity","Abiotic Resources","Water production capacity (Drinking water & Irrigation Water)","Wood Production Capacity"])
df_abs_box
# Out:
#    GICS Sub-Industry                  variable         value
# 0            Brewers          Working Capacity -2.950986e+08
# 1            Brewers          Working Capacity -3.142881e+08
# 2            Brewers          Working Capacity -3.210202e+08
# 3            Brewers          Working Capacity -6.232402e+07
# 4            Brewers          Working Capacity -6.990357e+07
# ..               ...                       ...           ...
# 75           Brewers  Wood Production Capacity  1.094936e+04
# 76           Brewers  Wood Production Capacity  1.026766e+04
# 77           Brewers  Wood Production Capacity  9.899783e+03
# 78           Brewers  Wood Production Capacity  9.927379e+03
# 79           Brewers  Wood Production Capacity  1.934170e+04
#
# [80 rows x 3 columns]

# %%
# Create the boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='variable', y='value', data=df_abs_box)
plt.xlabel('Metrics')
plt.ylabel('Percentage of Revenue (%)')
plt.title('Boxplot of Harvard Absolute Values')
plt.show()
# Out:
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Percentage of Revenue

# %%
df_rev = molson_df.copy()
for column in df_rev.loc[:,"Working Capacity":"SDG 15.5"]:
    #print(column)
    df_rev[column] = (df_rev[column] / df_rev['Revenue'])*100
df_rev.head()
# Out:
#       Year              Company Name                   Country  \
# 517   2019  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 2194  2018  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 3815  2017  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 5728  2016  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 7017  2015  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
#
#      GICS Sub-Industry  Environmental Intensity (Sales)  \
# 517            Brewers                        -6.596233
# 2194           Brewers                        -4.448054
# 3815           Brewers                        -4.381103
# 5728           Brewers                        -2.381480
# 7017           Brewers                        -3.841844
#
#       Environmental Intensity (Op Inc)  Total Environmental Cost  \
# 517                         -46.522794             -6.978419e+08
# 2194                        -36.115626             -4.790377e+08
# 3815                        -27.921920             -4.820440e+08
# 5728                        -23.947160             -1.163353e+08
# 7017                        -36.048861             -1.370578e+08
#
#       Working Capacity  Fish Production Capacity  Crop Production Capacity  \
# 517          -2.789370                 -0.000734                 -0.037033
# 2194         -2.918290                 -0.000764                 -0.038748
# 3815         -2.917623                 -0.000763                 -0.038739
# 5728         -1.275824                 -0.000388                 -0.016903
# 7017         -1.959455                 -0.000544                 -0.025996
#
#       ...  SDG 14.1  SDG 14.2  SDG 14.3  SDG 14.c  SDG 15.1  SDG 15.2  \
# 517   ... -0.000011 -0.000003 -0.000350 -0.000013  0.000143  0.000143
# 2194  ... -0.000011 -0.000003 -0.000365 -0.000013  0.000143  0.000143
# 3815  ... -0.000011 -0.000003 -0.000365 -0.000013  0.000143  0.000143
# 5728  ... -0.000011 -0.000003 -0.000177 -0.000013  0.000143  0.000143
# 7017  ... -0.000010 -0.000003 -0.000255 -0.000012  0.000143  0.000143
#
#       SDG 15.5  % Imputed       Revenue  Operating Income
# 517  -0.000116   0.059202  1.057940e+10      1.500000e+09
# 2194 -0.000121   0.083980  1.076960e+10      1.326400e+09
# 3815 -0.000121   0.085090  1.100280e+10      1.726400e+09
# 5728 -0.000053   0.140587  4.885000e+09      4.858000e+08
# 7017 -0.000081   0.094867  3.567500e+09      3.802000e+08
#
# [5 rows x 35 columns]

# %%
df_rev_box = df_rev.melt(id_vars='GICS Sub-Industry', value_vars=[ "Working Capacity","Fish Production Capacity","Crop Production Capacity","Meat Production Capacity","Biodiversity","Abiotic Resources","Water production capacity (Drinking water & Irrigation Water)","Wood Production Capacity"])
df_rev_box
# Out:
#    GICS Sub-Industry                  variable     value
# 0            Brewers          Working Capacity -2.789370
# 1            Brewers          Working Capacity -2.918290
# 2            Brewers          Working Capacity -2.917623
# 3            Brewers          Working Capacity -1.275824
# 4            Brewers          Working Capacity -1.959455
# ..               ...                       ...       ...
# 75           Brewers  Wood Production Capacity  0.000264
# 76           Brewers  Wood Production Capacity  0.000244
# 77           Brewers  Wood Production Capacity  0.000253
# 78           Brewers  Wood Production Capacity  0.000282
# 79           Brewers  Wood Production Capacity  0.000594
#
# [80 rows x 3 columns]

# %%
# Create the boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='variable', y='value', data=df_rev_box)
plt.xlabel('Metrics')
plt.ylabel('Percentage of Revenue (%)')
plt.title('Boxplot of Harvard as Percentage of Revenue')
plt.show()
# Out:
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Percentage of Op Income

# %%
df_opinc = molson_df.copy()
for column in df_opinc.loc[:,"Working Capacity":"SDG 15.5"]:
    #print(column)
    df_opinc[column] = (df_opinc[column] / df_opinc['Operating Income'])*100
df_opinc.head()
# Out:
#       Year              Company Name                   Country  \
# 517   2019  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 2194  2018  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 3815  2017  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 5728  2016  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 7017  2015  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
#
#      GICS Sub-Industry  Environmental Intensity (Sales)  \
# 517            Brewers                        -6.596233
# 2194           Brewers                        -4.448054
# 3815           Brewers                        -4.381103
# 5728           Brewers                        -2.381480
# 7017           Brewers                        -3.841844
#
#       Environmental Intensity (Op Inc)  Total Environmental Cost  \
# 517                         -46.522794             -6.978419e+08
# 2194                        -36.115626             -4.790377e+08
# 3815                        -27.921920             -4.820440e+08
# 5728                        -23.947160             -1.163353e+08
# 7017                        -36.048861             -1.370578e+08
#
#       Working Capacity  Fish Production Capacity  Crop Production Capacity  \
# 517         -19.673242                 -0.005177                 -0.261191
# 2194        -23.694822                 -0.006199                 -0.314608
# 3815        -18.594774                 -0.004865                 -0.246892
# 5728        -12.829153                 -0.003901                 -0.169973
# 7017        -18.385999                 -0.005103                 -0.243923
#
#       ...  SDG 14.1  SDG 14.2  SDG 14.3  SDG 14.c  SDG 15.1  SDG 15.2  \
# 517   ... -0.000074 -0.000022 -0.002468 -0.000088  0.001012  0.001012
# 2194  ... -0.000085 -0.000025 -0.002961 -0.000102  0.001165  0.001165
# 3815  ... -0.000067 -0.000020 -0.002324 -0.000080  0.000914  0.000914
# 5728  ... -0.000106 -0.000031 -0.001779 -0.000126  0.001443  0.001443
# 7017  ... -0.000098 -0.000029 -0.002392 -0.000117  0.001340  0.001340
#
#       SDG 15.5  % Imputed       Revenue  Operating Income
# 517  -0.000817   0.059202  1.057940e+10      1.500000e+09
# 2194 -0.000985   0.083980  1.076960e+10      1.326400e+09
# 3815 -0.000773   0.085090  1.100280e+10      1.726400e+09
# 5728 -0.000532   0.140587  4.885000e+09      4.858000e+08
# 7017 -0.000763   0.094867  3.567500e+09      3.802000e+08
#
# [5 rows x 35 columns]

# %%
df_opinc_box = df_opinc.melt(id_vars='GICS Sub-Industry', value_vars=[ "Working Capacity","Fish Production Capacity","Crop Production Capacity","Meat Production Capacity","Biodiversity","Abiotic Resources","Water production capacity (Drinking water & Irrigation Water)","Wood Production Capacity"])
df_opinc_box
# Out:
#    GICS Sub-Industry                  variable      value
# 0            Brewers          Working Capacity -19.673242
# 1            Brewers          Working Capacity -23.694822
# 2            Brewers          Working Capacity -18.594774
# 3            Brewers          Working Capacity -12.829153
# 4            Brewers          Working Capacity -18.385999
# ..               ...                       ...        ...
# 75           Brewers  Wood Production Capacity   0.002292
# 76           Brewers  Wood Production Capacity   0.002222
# 77           Brewers  Wood Production Capacity   0.002038
# 78           Brewers  Wood Production Capacity   0.002149
# 79           Brewers  Wood Production Capacity   0.004467
#
# [80 rows x 3 columns]

# %%
# Create the boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='variable', y='value', data=df_opinc_box)
plt.xlabel('Metrics')
plt.ylabel('Percentage of Operating Income (%)')
plt.title('Boxplot of Harvard as Percentage of Op income')
plt.show()
# Out:
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## On Total Environmental Cost

# %%
df_cost = molson_df.copy()
for column in df_cost.loc[:,"Working Capacity":"SDG 15.5"]:
    #print(column)
    df_cost[column] = (df_cost[column] / df_cost['Total Environmental Cost']) * 100
df_cost.head()
# Out:
#       Year              Company Name                   Country  \
# 517   2019  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 2194  2018  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 3815  2017  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 5728  2016  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
# 7017  2015  MOLSON COORS BEVERAGE CO  UNITED STATES OF AMERICA
#
#      GICS Sub-Industry  Environmental Intensity (Sales)  \
# 517            Brewers                        -6.596233
# 2194           Brewers                        -4.448054
# 3815           Brewers                        -4.381103
# 5728           Brewers                        -2.381480
# 7017           Brewers                        -3.841844
#
#       Environmental Intensity (Op Inc)  Total Environmental Cost  \
# 517                         -46.522794             -6.978419e+08
# 2194                        -36.115626             -4.790377e+08
# 3815                        -27.921920             -4.820440e+08
# 5728                        -23.947160             -1.163353e+08
# 7017                        -36.048861             -1.370578e+08
#
#       Working Capacity  Fish Production Capacity  Crop Production Capacity  \
# 517          42.287318                  0.011128                  0.561427
# 2194         65.608226                  0.017165                  0.871113
# 3815         66.595613                  0.017424                  0.884223
# 5728         53.572751                  0.016288                  0.709784
# 7017         51.002996                  0.014155                  0.676647
#
#       ...  SDG 14.1  SDG 14.2  SDG 14.3  SDG 14.c  SDG 15.1  SDG 15.2  \
# 517   ...  0.000160  0.000047  0.005306  0.000190 -0.002175 -0.002175
# 2194  ...  0.000237  0.000069  0.008199  0.000282 -0.003225 -0.003225
# 3815  ...  0.000240  0.000071  0.008323  0.000286 -0.003274 -0.003274
# 5728  ...  0.000442  0.000130  0.007428  0.000527 -0.006024 -0.006024
# 7017  ...  0.000273  0.000080  0.006636  0.000325 -0.003717 -0.003717
#
#       SDG 15.5  % Imputed       Revenue  Operating Income
# 517   0.001757   0.059202  1.057940e+10      1.500000e+09
# 2194  0.002726   0.083980  1.076960e+10      1.326400e+09
# 3815  0.002767   0.085090  1.100280e+10      1.726400e+09
# 5728  0.002222   0.140587  4.885000e+09      4.858000e+08
# 7017  0.002118   0.094867  3.567500e+09      3.802000e+08
#
# [5 rows x 35 columns]

# %%
df_melted = df_cost.melt(id_vars='GICS Sub-Industry', value_vars=[ "Working Capacity","Fish Production Capacity","Crop Production Capacity","Meat Production Capacity","Biodiversity","Abiotic Resources","Water production capacity (Drinking water & Irrigation Water)","Wood Production Capacity"])
df_melted
# Out:
#    GICS Sub-Industry                  variable      value
# 0            Brewers          Working Capacity  42.287318
# 1            Brewers          Working Capacity  65.608226
# 2            Brewers          Working Capacity  66.595613
# 3            Brewers          Working Capacity  53.572751
# 4            Brewers          Working Capacity  51.002996
# ..               ...                       ...        ...
# 75           Brewers  Wood Production Capacity  -0.007287
# 76           Brewers  Wood Production Capacity  -0.006235
# 77           Brewers  Wood Production Capacity  -0.007052
# 78           Brewers  Wood Production Capacity  -0.007270
# 79           Brewers  Wood Production Capacity  -0.013067
#
# [80 rows x 3 columns]

# %%
# Create the boxplot
plt.figure(figsize=(20, 8))
sns.boxplot(x='variable', y='value', data=df_melted)
plt.xlabel('Metrics')
plt.ylabel('Percentage of Total Cost (%)')
plt.title('Boxplot of Harvard as Percentage of Total Environmental Cost')
plt.show()
# Out:
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## On SDGs

# %%
df_opinc_box = df_opinc.melt(id_vars='GICS Sub-Industry', value_vars=df_opinc.loc[:,"SDG 1.5":"SDG 15.5"])
df_opinc_box
# Out:
#     GICS Sub-Industry  variable      value
# 0             Brewers   SDG 1.5  -8.748568
# 1             Brewers   SDG 1.5 -10.539988
# 2             Brewers   SDG 1.5  -8.271360
# 3             Brewers   SDG 1.5  -5.660726
# 4             Brewers   SDG 1.5  -8.153803
# ..                ...       ...        ...
# 165           Brewers  SDG 15.5  -0.000760
# 166           Brewers  SDG 15.5  -0.000838
# 167           Brewers  SDG 15.5  -0.000498
# 168           Brewers  SDG 15.5  -0.000545
# 169           Brewers  SDG 15.5  -0.000372
#
# [170 rows x 3 columns]

# %%
# Create the boxplot
plt.figure(figsize=(20, 8))
sns.boxplot(x='variable', y='value', data=df_opinc_box)
plt.xlabel('Metrics')
plt.ylabel('Percentage of Operating Income (%)')
plt.title('Boxplot of SDGs as Percentage of Op income')
plt.show()
# Out:
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
for column in df_opinc.loc[:,"SDG 1.5":"SDG 15.5"]:  # Exclude the 'Year' column
    sns.lineplot(x='Year', y=column, data=df_opinc, label=column)
sns.lineplot(x='Year', y="Environmental Intensity (Op Inc)", data=df_opinc, label="Total Cost")

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Value %')
plt.title('SDGs Changes over time Molson')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend position

# Show the plot
plt.show()
# Out:
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\alexa\mambaforge\envs\spm\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Further Analysis here
