# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import the Excel

# %%
# Load the dataset
df = pd.read_excel("Models\IWA_new.xlsx", sheet_name='Final Raw Sample(0%)')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14035 entries, 0 to 14034
# Data columns (total 36 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Year                                                           14035 non-null  int64
#  1   Company Name                                                   14035 non-null  object
#  2   Country                                                        14014 non-null  object
#  3   GICS Sub-Industry                                              14035 non-null  object
#  4   Industry (Exiobase)                                            14035 non-null  object
#  5   Environmental Intensity (Sales)                                14035 non-null  float64
#  6   Environmental Intensity (Op Inc)                               13273 non-null  float64
#  7   Revenue                                                        14035 non-null  float64
#  8   Operating Income                                               13273 non-null  float64
#  9   Total Environmental Cost                                       14035 non-null  float64
#  10  Working Capacity                                               14035 non-null  float64
#  11  Fish Production Capacity                                       14035 non-null  float64
#  12  Crop Production Capacity                                       14035 non-null  float64
#  13  Meat Production Capacity                                       14035 non-null  float64
#  14  Biodiversity                                                   14035 non-null  float64
#  15  Abiotic Resources                                              14035 non-null  float64
#  16  Water production capacity (Drinking water & Irrigation Water)  14035 non-null  float64
#  17  Wood Production Capacity                                       14035 non-null  float64
#  18  SDG 1.5                                                        14035 non-null  float64
#  19  SDG 2.1                                                        14035 non-null  float64
#  20  SDG 2.2                                                        14035 non-null  float64
#  21  SDG 2.3                                                        14035 non-null  float64
#  22  SDG 2.4                                                        14035 non-null  float64
#  23  SDG 3.3                                                        14035 non-null  float64
#  24  SDG 3.4                                                        14035 non-null  float64
#  25  SDG 3.9                                                        14035 non-null  float64
#  26  SDG 6                                                          14035 non-null  float64
#  27  SDG 12.2                                                       14035 non-null  float64
#  28  SDG 14.1                                                       14035 non-null  float64
#  29  SDG 14.2                                                       14035 non-null  float64
#  30  SDG 14.3                                                       14035 non-null  float64
#  31  SDG 14.c                                                       14035 non-null  float64
#  32  SDG 15.1                                                       14035 non-null  float64
#  33  SDG 15.2                                                       14035 non-null  float64
#  34  SDG 15.5                                                       14035 non-null  float64
#  35  % Imputed                                                      14035 non-null  float64
# dtypes: float64(31), int64(1), object(4)
# memory usage: 3.9+ MB

# %%
df.isna().sum()
# Out:
# Year                                                               0
# Company Name                                                       0
# Country                                                           21
# GICS Sub-Industry                                                  0
# Industry (Exiobase)                                                0
# Environmental Intensity (Sales)                                    0
# Environmental Intensity (Op Inc)                                 762
# Revenue                                                            0
# Operating Income                                                 762
# Total Environmental Cost                                           0
# Working Capacity                                                   0
# Fish Production Capacity                                           0
# Crop Production Capacity                                           0
# Meat Production Capacity                                           0
# Biodiversity                                                       0
# Abiotic Resources                                                  0
# Water production capacity (Drinking water & Irrigation Water)      0
# Wood Production Capacity                                           0
# SDG 1.5                                                            0
# SDG 2.1                                                            0
# SDG 2.2                                                            0
# SDG 2.3                                                            0
# SDG 2.4                                                            0
# SDG 3.3                                                            0
# SDG 3.4                                                            0
# SDG 3.9                                                            0
# SDG 6                                                              0
# SDG 12.2                                                           0
# SDG 14.1                                                           0
# SDG 14.2                                                           0
# SDG 14.3                                                           0
# SDG 14.c                                                           0
# SDG 15.1                                                           0
# SDG 15.2                                                           0
# SDG 15.5                                                           0
# % Imputed                                                          0
# dtype: int64

# %%
df.describe()
# Out:
#                Year  Environmental Intensity (Sales)  \
# count  14035.000000                     14035.000000
# mean    2014.962166                        -0.111298
# std        2.788529                         0.268221
# min     2010.000000                        -1.992787
# 25%     2013.000000                        -0.091389
# 50%     2015.000000                        -0.020290
# 75%     2017.000000                        -0.006881
# max     2019.000000                         1.903596
#
#        Environmental Intensity (Op Inc)       Revenue  Operating Income  \
# count                      13273.000000  1.403500e+04      1.327300e+04
# mean                          -2.031901  1.344066e+10      1.611401e+09
# std                           24.867742  3.050169e+10      3.894498e+09
# min                        -2462.894168  8.000000e+03     -1.490280e+09
# 25%                           -0.915317  1.373984e+09      1.560475e+08
# 50%                           -0.215528  4.145670e+09      4.288750e+08
# 75%                           -0.056225  1.246504e+10      1.272216e+09
# max                           79.945145  6.740459e+11      7.071866e+10
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# count              1.403500e+04      1.403500e+04              1.403500e+04
# mean              -1.141007e+09     -1.005167e+09             -2.923450e+05
# std                4.907451e+09      4.345204e+09              1.160298e+06
# min               -1.144424e+11     -7.791808e+10             -1.888769e+07
# 25%               -4.453716e+08     -3.962473e+08             -1.037233e+05
# 50%               -9.371568e+07     -8.230080e+07             -2.227284e+04
# 75%               -2.046964e+07     -1.843801e+07             -5.149606e+03
# max                5.211102e+10      5.099029e+10              1.164796e+07
#
#        Crop Production Capacity  Meat Production Capacity  ...         SDG 6  \
# count              1.403500e+04              1.403500e+04  ...  1.403500e+04
# mean              -1.303232e+07             -3.030495e+06  ... -1.149481e+08
# std                5.556004e+07              1.291882e+07  ...  1.334991e+09
# min               -9.241874e+08             -2.161508e+08  ... -7.691509e+10
# 25%               -5.217459e+06             -1.205465e+06  ... -2.037187e+07
# 50%               -1.078849e+06             -2.510979e+05  ... -2.610187e+06
# 75%               -2.412052e+05             -5.618250e+04  ... -2.885597e+05
# max                6.781193e+08              1.589838e+08  ...  2.093348e+10
#
#            SDG 12.2       SDG 14.1       SDG 14.2      SDG 14.3  \
# count  1.403500e+04   14035.000000   14035.000000  1.403500e+04
# mean  -4.565512e+06   -4857.481987   -1922.298027 -1.375687e+05
# std    1.001810e+08   24492.756766   15213.403370  5.474642e+05
# min   -4.485891e+09 -483554.391700 -637843.776412 -9.017876e+06
# 25%   -9.082788e+04    -600.134099    -216.741453 -4.924349e+04
# 50%   -1.090588e+04     -89.968052     -29.498334 -1.072995e+04
# 75%   -1.868184e+03     -14.501556      -4.347541 -2.451070e+03
# max    0.000000e+00  189956.254000       0.005117  5.825526e+06
#
#             SDG 14.c      SDG 15.1      SDG 15.2      SDG 15.5     % Imputed
# count   14035.000000  1.403500e+04  1.403500e+04  1.403500e+04  14035.000000
# 50%   -1.132753e+04     -91.267921     -30.194350 -1.083142e+04
# 75%   -1.929421e+03     -14.909830      -4.469561 -2.531129e+03
# max    0.000000e+00  189956.254000       0.005117  5.825526e+06
#
#             SDG 14.c      SDG 15.1      SDG 15.2      SDG 15.5     % Imputed
# count   13255.000000  1.325500e+04  1.325500e+04  1.325500e+04  13255.000000
# mean    -5721.743941  5.843617e+04  1.381861e+04 -4.073476e+04      0.065964
# std     29352.770698  3.575647e+05  2.339473e+06  1.699492e+05      0.067471
# min   -576362.772700 -3.991837e+06 -1.591757e+08 -2.907937e+06      0.000000
# 25%      -717.682603  7.854620e+01  6.965077e+01 -1.657232e+04      0.011382
# 50%      -108.784933  7.529707e+02  7.171479e+02 -3.499918e+03      0.039636
# 75%       -17.771467  6.470874e+03  6.261595e+03 -7.919335e+02      0.104491
# max    226412.474000  7.146112e+06  7.146112e+06  2.122135e+06      0.249796
#
# [8 rows x 32 columns]

# %% [markdown]
# # Check outliers in Sales

# %%
outlier_check = df.loc[:,["Environmental Intensity (Op Inc)","Environmental Intensity (Sales)"]].abs()
outlier_check
# Out:
#        Environmental Intensity (Op Inc)  Environmental Intensity (Sales)
# 0                              0.130254                         0.028872
# 1                              0.034656                         0.016772
# 2                              0.094878                         0.015297
# 4                              0.050957                         0.006993
# 5                              0.072749                         0.006657
# ...                                 ...                              ...
# 14030                         11.014730                         0.213669
# 14031                          6.618900                         0.202556
# 14032                         11.047016                         0.196883
# 14033                         79.945145                         0.149515
# 14034                         31.667986                         0.137662
#
# [13255 rows x 2 columns]

# %%
column_name = 'Environmental Intensity (Sales)'

threshold = 1

# Mask to determine values below and above threshold
below_threshold = outlier_check[column_name] <= threshold
above_threshold_count = len(outlier_check[column_name][~below_threshold])

# Create bins up to the threshold
bins = np.linspace(0, threshold, 100)  # 49 bins up to the threshold

# Plot histogram with custom bins
n, bins, patches = plt.hist(outlier_check[column_name][below_threshold].dropna(), bins=bins, edgecolor='k')

# Manually add a bar for values above the threshold
plt.bar(threshold, above_threshold_count, width=(threshold - bins[-2]), color=plt.cm.viridis(0.6), edgecolor='k')

# Set x-axis limit
plt.xlim(0, 1.1*threshold)  # Increase a bit to see the last bar clearly

# Display the plot
plt.title("Histogram for " + column_name)
plt.xlabel(column_name)
plt.ylabel("Frequency")
plt.show()

# %%
# Calculate the 0.15th and 99.85th percentile
pct_0_15 = np.percentile(df['Environmental Intensity (Sales)'], 0.5)
pct_99_85 = np.percentile(df['Environmental Intensity (Sales)'], 99.5)

# Remove the data points outside the 0.15th and 99.85th percentile
df_new_opinc = df[(df['Environmental Intensity (Sales)'] >= pct_0_15) & (df['Environmental Intensity (Sales)'] <= pct_99_85)].copy()
df_new_opinc.describe()
# Out:
#                Year  Environmental Intensity (Sales)  \
# count  13121.000000                     13121.000000
# mean    2014.970810                        -0.104812
# std        2.788858                         0.229487
# 75%       -17.566231  6.132890e+03  5.906305e+03 -8.023413e+02      0.105190
# max    226412.474000  7.146112e+06  7.146112e+06  7.777353e+05      0.249715
#
# [8 rows x 32 columns]

# %%
outlier_check = df_new_opinc.loc[:,["Environmental Intensity (Op Inc)","Environmental Intensity (Sales)"]].abs()
outlier_check
# Out:
#        Environmental Intensity (Op Inc)  Environmental Intensity (Sales)
# 0                              0.130254                         0.028872
# 1                              0.034656                         0.016772
# 2                              0.094878                         0.015297
# 4                              0.050957                         0.006993
# 5                              0.072749                         0.006657
# ...                                 ...                              ...
# 14030                         11.014730                         0.213669
# 14031                          6.618900                         0.202556
# 14032                         11.047016                         0.196883
# 14033                         79.945145                         0.149515
# 14034                         31.667986                         0.137662
#
# [13121 rows x 2 columns]

# %%
column_name = 'Environmental Intensity (Sales)'

threshold = 1

# Mask to determine values below and above threshold
below_threshold = outlier_check[column_name] <= threshold
above_threshold_count = len(outlier_check[column_name][~below_threshold])

# Create bins up to the threshold
bins = np.linspace(0, threshold, 100)  # 49 bins up to the threshold

# Plot histogram with custom bins
n, bins, patches = plt.hist(outlier_check[column_name][below_threshold].dropna(), bins=bins, edgecolor='k')

# Manually add a bar for values above the threshold
plt.bar(threshold, above_threshold_count, width=(threshold - bins[-2]), color=plt.cm.viridis(0.6), edgecolor='k')

# Set x-axis limit
plt.xlim(0, 1.1*threshold)  # Increase a bit to see the last bar clearly

# Display the plot
plt.title("Histogram for " + column_name)
plt.xlabel(column_name)
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Checking outliers in Op Inc

# %%
outlier_check = df.loc[:,["Environmental Intensity (Op Inc)","Environmental Intensity (Sales)"]].abs()
outlier_check
# Out:
#        Environmental Intensity (Op Inc)  Environmental Intensity (Sales)
# 0                              0.130254                         0.028872
# 1                              0.034656                         0.016772
# 2                              0.094878                         0.015297
# 4                              0.050957                         0.006993
# 5                              0.072749                         0.006657
# ...                                 ...                              ...
# 14030                         11.014730                         0.213669
# 14031                          6.618900                         0.202556
# 14032                         11.047016                         0.196883
# 14033                         79.945145                         0.149515
# 14034                         31.667986                         0.137662
#
# [13255 rows x 2 columns]

# %%
column_name = 'Environmental Intensity (Op Inc)'

threshold = 3

# Mask to determine values below and above threshold
below_threshold = outlier_check[column_name] <= threshold
above_threshold_count = len(outlier_check[column_name][~below_threshold])

# Create bins up to the threshold
bins = np.linspace(0, threshold, 100)  # 49 bins up to the threshold

# Plot histogram with custom bins
n, bins, patches = plt.hist(outlier_check[column_name][below_threshold].dropna(), bins=bins, edgecolor='k')

# Manually add a bar for values above the threshold
plt.bar(threshold, above_threshold_count, width=(threshold - bins[-2]), color=plt.cm.viridis(0.6), edgecolor='k')

# Set x-axis limit
plt.xlim(0, 1.1*threshold)  # Increase a bit to see the last bar clearly

# Display the plot
plt.title("Histogram for " + column_name)
plt.xlabel(column_name)
plt.ylabel("Frequency")
plt.show()

# %%
# Calculate the 0.15th and 99.85th percentile
pct_0_15 = np.percentile(df['Environmental Intensity (Op Inc)'], 5)
pct_99_85 = np.percentile(df['Environmental Intensity (Op Inc)'], 95)

# Remove the data points outside the 0.15th and 99.85th percentile
df_new_opinc = df[(df['Environmental Intensity (Op Inc)'] >= pct_0_15) & (df['Environmental Intensity (Op Inc)'] <= pct_99_85)].copy()
df_new_opinc.describe()
# Out:
#                Year  Environmental Intensity (Sales)  \
# count  11929.000000                     11929.000000
# mean    2014.961522                        -0.083508
# std        2.790129                         0.178153
# min     2010.000000                        -1.830113
# 25%     2013.000000                        -0.075592
# 50%     2015.000000                        -0.019990
# 75%     2017.000000                        -0.007731
# max     2019.000000                        -0.000274
#
#        Environmental Intensity (Op Inc)       Revenue  Operating Income  \
# count                      11929.000000  1.192900e+04      1.192900e+04
# mean                          -0.769564  1.395170e+10      1.646383e+09
# std                            1.318705  3.197278e+10      4.012413e+09
# min                           -7.332231  8.108000e+06      3.330000e+05
# 25%                           -0.775541  1.494945e+09      1.594462e+08
# 50%                           -0.215501  4.278341e+09      4.373993e+08
# 75%                           -0.064696  1.276793e+10      1.269600e+09
# max                           -0.005902  6.740459e+11      7.071866e+10
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# count              1.192900e+04      1.192900e+04              1.192900e+04
# mean              -8.451087e+08     -7.403831e+08             -2.111687e+05
# std                3.257983e+09      2.790293e+09              8.302536e+05
# min               -7.181091e+10     -6.297616e+10             -1.888769e+07
# 25%               -4.066208e+08     -3.612795e+08             -8.896811e+04
# 50%               -9.721148e+07     -8.524208e+07             -2.155014e+04
# 75%               -2.468123e+07     -2.223636e+07             -5.608706e+03
# max               -3.501477e+04      6.605561e+07             -1.055557e+01
#
#        Crop Production Capacity  Meat Production Capacity  ...         SDG 6  \
# count              1.192900e+04              1.192900e+04  ...  1.192900e+04
# mean              -9.714198e+06             -2.249832e+06  ... -9.132254e+07
# std                3.679968e+07              8.461970e+06  ...  9.602482e+08
# min               -8.444974e+08             -1.969808e+08  ... -4.996480e+10
# 25%               -4.753245e+06             -1.102952e+06  ... -1.842922e+07
# 50%               -1.121579e+06             -2.613635e+05  ... -2.664930e+06
# 75%               -2.925717e+05             -6.783225e+04  ... -3.486780e+05
# max                9.923826e+06              1.955971e+06  ...  1.975618e+09
#
#            SDG 12.2       SDG 14.1       SDG 14.2      SDG 14.3  \
# count  1.192900e+04   11929.000000   11929.000000  1.192900e+04
# mean  -1.228337e+06   -3237.223823   -1117.068436 -1.000904e+05
# std    1.740386e+07   17748.928500    6818.355533  3.922224e+05
# min   -8.256771e+08 -394404.231000 -257330.374597 -9.017876e+06
# 25%   -7.847364e+04    -480.937528    -189.626882 -4.315692e+04
# 50%   -1.081074e+04     -82.363030     -28.428080 -1.045764e+04
# 75%   -1.972148e+03     -15.169300      -4.560104 -2.709500e+03
# max    0.000000e+00       0.000000       0.000000 -4.780361e+00
#
#             SDG 14.c      SDG 15.1      SDG 15.2      SDG 15.5     % Imputed
# count   11929.000000  1.192900e+04  1.192900e+04  1.192900e+04  11929.000000
# mean    -3858.542763  4.142362e+04 -6.926603e+03 -3.071532e+04      0.064316
# std     21155.472514  2.548763e+05  2.449830e+06  1.157309e+05      0.065788
# min   -470102.061000 -8.257140e+05 -1.591757e+08 -2.649820e+06      0.000000
# 25%      -573.243656  8.178744e+01  7.430980e+01 -1.492168e+04      0.011650
# 50%       -98.170930  7.045748e+02  6.793615e+02 -3.539486e+03      0.038520
# 75%       -18.080737  5.175013e+03  5.009102e+03 -9.222021e+02      0.100514
# max         0.000000  5.715878e+06  5.715878e+06  2.340258e+03      0.249715
#
# [8 rows x 32 columns]

# %%
outlier_check = df_new_opinc.loc[:,["Environmental Intensity (Op Inc)","Environmental Intensity (Sales)"]].abs()
outlier_check
# Out:
#        Environmental Intensity (Op Inc)  Environmental Intensity (Sales)
# 0                              0.130254                         0.028872
# 1                              0.034656                         0.016772
# 2                              0.094878                         0.015297
# 4                              0.050957                         0.006993
# 5                              0.072749                         0.006657
# ...                                 ...                              ...
# 14020                          0.372236                         0.017119
# 14021                          0.369835                         0.013895
# 14022                          0.331813                         0.010148
# 14023                          0.146504                         0.004154
# 14024                          0.022646                         0.000415
#
# [11929 rows x 2 columns]

# %%
column_name = 'Environmental Intensity (Op Inc)'

threshold = 3

# Mask to determine values below and above threshold
below_threshold = outlier_check[column_name] <= threshold
above_threshold_count = len(outlier_check[column_name][~below_threshold])

# Create bins up to the threshold
bins = np.linspace(0, threshold, 100)  # 49 bins up to the threshold

# Plot histogram with custom bins
n, bins, patches = plt.hist(outlier_check[column_name][below_threshold].dropna(), bins=bins, edgecolor='k')

# Manually add a bar for values above the threshold
plt.bar(threshold, above_threshold_count, width=(threshold - bins[-2]), color=plt.cm.viridis(0.6), edgecolor='k')

# Set x-axis limit
plt.xlim(0, 1.1*threshold)  # Increase a bit to see the last bar clearly

# Display the plot
plt.title("Histogram for " + column_name)
plt.xlabel(column_name)
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Filter for only the Brewery Category

# %%
brewery_df = df[df['GICS Sub-Industry'] == 'Brewers']
brewery_df.describe()
# Out:
#               Year  Environmental Intensity (Sales)  \
# count    97.000000                        97.000000
# mean   2014.711340                        -0.045118
# std       2.890209                         0.077386
# min    2010.000000                        -0.575096
# 25%    2012.000000                        -0.043425
# 50%    2015.000000                        -0.024146
# 75%    2017.000000                        -0.018988
# max    2019.000000                        -0.010659
#
#        Environmental Intensity (Op Inc)       Revenue  Operating Income  \
# count                         97.000000  9.700000e+01      9.700000e+01
# mean                          -0.770383  1.599170e+10      2.667682e+09
# std                            2.903896  1.140813e+10      3.358183e+09
# min                          -21.560390  2.061860e+08      4.795000e+06
# 25%                           -0.356920  4.885000e+09      4.619000e+08
# 50%                           -0.195663  1.489021e+10      1.500000e+09
# 75%                           -0.160548  2.330599e+10      3.218938e+09
# max                           -0.057862  5.248464e+10      1.547524e+10
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# count              9.700000e+01      9.700000e+01                 97.000000
# mean              -4.739359e+08     -3.904063e+08            -101656.700281
# std                4.565047e+08      4.173841e+08             102903.714094
# min               -2.014783e+09     -1.826059e+09            -450381.544382
# 25%               -5.325855e+08     -4.432719e+08            -115132.101397
# 50%               -3.077938e+08     -2.780951e+08             -77275.994208
# 75%               -2.053146e+08     -1.363239e+08             -28181.370530
# max               -5.663652e+07     -3.412893e+07             -10348.794634
#
#        Crop Production Capacity  Meat Production Capacity  ...         SDG 6  \
# count              9.700000e+01              9.700000e+01  ...  9.700000e+01
# mean              -5.184281e+06             -1.206193e+06  ... -7.691905e+07
# std                5.627911e+06              1.301558e+06  ...  9.448134e+07
# min               -2.455600e+07             -5.674157e+06  ... -4.916364e+08
# 25%               -5.939257e+06             -1.380063e+06  ... -8.469211e+07
# 50%               -3.688012e+06             -8.614216e+05  ... -5.547273e+07
# 75%               -1.528990e+06             -3.583527e+05  ... -1.627385e+07
# max               -4.132155e+05             -9.282468e+04  ... -4.091458e+05
#
#             SDG 12.2     SDG 14.1     SDG 14.2       SDG 14.3     SDG 14.c  \
# count      97.000000    97.000000    97.000000      97.000000    97.000000
# mean  -126737.343390 -1067.378026  -226.408236  -49229.743204 -1272.239419
# std    117967.725419  1008.590093   284.392753   50532.923593  1202.168344
# min   -432104.047468 -3914.291085 -1760.270030 -220370.587233 -4665.559245
# 25%   -169257.315878 -1634.749760  -287.744785  -55954.671146 -1948.506560
# 50%    -80676.306954  -568.200650  -140.119558  -36352.598366  -677.255150
# 75%    -27982.157190  -208.514000   -98.703951  -13210.562858  -248.534000
# max     -1511.826537   -21.695746    -6.372799   -4469.580254   -25.859801
#
#            SDG 15.1      SDG 15.2      SDG 15.5  % Imputed
# count     97.000000     97.000000     97.000000  97.000000
# mean   14262.081583  11394.776171 -16245.525447   0.053349
# std    15314.093566  21682.138626  17397.521030   0.050661
# min    -9527.183447 -63221.871316 -75893.622336   0.000854
# 25%     2331.455963   2331.455963 -18479.781729   0.010532
# 50%     7657.845811   7657.845811 -11508.130189   0.029563
# 75%    21553.054908  21436.900812  -4784.980253   0.085090
# max    56659.806086  56659.806086  -1607.746022   0.220991
#
# [8 rows x 32 columns]

# %%
# Group the data by "Company Name" and count unique years for each group
company_years_count = brewery_df.groupby("Company Name")["Year"].nunique()

# Filter companies with at least 10 years of data
filtered_companies = company_years_count[company_years_count >= 8].index

# Create a new DataFrame with only the companies that meet the criteria
filtered_df = brewery_df[brewery_df["Company Name"].isin(filtered_companies)]
#filtered_df.shape

# %%
filtered_df.describe()
# Out:
#              Year  Environmental Intensity (Sales)  \
# count    70.00000                        70.000000
# mean   2014.50000                        -0.027003
# std       2.89302                         0.012157
# min    2010.00000                        -0.065962
# 25%    2012.00000                        -0.035354
# 50%    2014.50000                        -0.023407
# 75%    2017.00000                        -0.018978
# max    2019.00000                        -0.011214
#
#        Environmental Intensity (Op Inc)       Revenue  Operating Income  \
# count                         70.000000  7.000000e+01      7.000000e+01
# mean                          -0.204549  2.015234e+10      3.331240e+09
# std                            0.074832  1.059868e+10      3.612891e+09
# min                           -0.465228  3.254400e+09      3.802000e+08
# 25%                           -0.238364  1.129416e+10      1.272106e+09
# 50%                           -0.180956  1.928265e+10      1.769335e+09
# 75%                           -0.157068  2.614523e+10      3.360271e+09
# max                           -0.105084  5.248464e+10      1.547524e+10
#
#        Total Environmental Cost  Working Capacity  Fish Production Capacity  \
# count              7.000000e+01      7.000000e+01                 70.000000
# mean              -5.563805e+08     -4.844918e+08            -127068.231626
# std                4.944295e+08      4.540115e+08             110092.056997
# min               -2.014783e+09     -1.826059e+09            -450381.544382
# 25%               -5.507975e+08     -4.867061e+08            -148900.236218
# 50%               -3.740234e+08     -3.410548e+08             -82246.522644
# 75%               -2.681731e+08     -2.302089e+08             -63079.996778
# max               -1.163353e+08     -3.412893e+07             -16642.815125
#
#        Crop Production Capacity  Meat Production Capacity  ...         SDG 6  \
# count              7.000000e+01              7.000000e+01  ...  7.000000e+01
# mean              -6.462546e+06             -1.502975e+06  ... -6.367234e+07
# std                6.114380e+06              1.412740e+06  ...  6.135701e+07
# min               -2.455600e+07             -5.674157e+06  ... -3.977745e+08
# 25%               -6.434653e+06             -1.505564e+06  ... -6.993979e+07
# 50%               -4.532210e+06             -1.059493e+06  ... -4.953376e+07
# 75%               -3.034155e+06             -7.110098e+05  ... -1.810200e+07
# max               -4.132155e+05             -9.282468e+04  ... -2.788056e+06
#
#             SDG 12.2     SDG 14.1    SDG 14.2       SDG 14.3     SDG 14.c  \
# count      70.000000    70.000000   70.000000      70.000000    70.000000
# mean  -140527.146413 -1367.525225 -170.547294  -61665.270426 -1629.993738
# std    114003.558157  1030.595112   80.227848   54080.879116  1228.396777
# min   -403771.445248 -3914.291085 -340.074642 -220370.587233 -4665.559245
# 25%   -189751.073506 -2127.488514 -234.302990  -71518.268872 -2535.816446
# 50%   -150769.868084 -1304.463639 -140.119558  -40217.642561 -1554.828770
# 75%    -36124.450205  -382.812300 -109.910728  -30818.126395  -456.285296
# max    -22823.399686   -71.728819  -67.059773   -7733.188929   -85.495700
#
#            SDG 15.1      SDG 15.2      SDG 15.5  % Imputed
# count     70.000000     70.000000     70.000000  70.000000
# mean   19185.360309  19167.956733 -20236.689958   0.041639
# std    15100.755939  15098.402582  18864.169322   0.037091
# min      500.041855    500.041855 -75893.622336   0.006961
# 25%     5208.278379   5208.278379 -20739.504315   0.010498
# 50%    17761.303792  17698.605074 -14150.150363   0.023569
# 75%    30795.636819  30795.636819  -9660.469889   0.076415
# max    56659.806086  56659.806086  -1611.055691   0.151424
#
# [8 rows x 32 columns]

# %% [markdown]
# We see no outliers in the brewery category
